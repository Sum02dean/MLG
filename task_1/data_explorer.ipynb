# %%
from data_loader import *

all_genes = pd.concat([load_train_genes(), load_test_genes()])

# Number of genes per chromosome
all_genes['chr'].value_counts().plot.bar(x='Target Value', y='Number of Occurrences')
# Out:
# <AxesSubplot:>
